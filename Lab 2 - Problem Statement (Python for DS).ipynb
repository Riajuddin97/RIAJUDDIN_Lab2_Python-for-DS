# %% [markdown]
# ## Lab Session

# %% [markdown]
# ### Learning Objective:
# - Working with data using python libaries.
# - Data Visualization.
# - Exploratory data analysis and data preprocessing.
# - Building a Linear regression model to predict the tip amount based on different input features.

# %% [markdown]
# ### About the dataset (Customer Tip Data)
#
# #### Dataset Source: https://www.kaggle.com/datasets/ranjeetjain3/seaborn-tips-dataset
#
# The dataset contains information about the 244 orders served at a restaurant in the United States. Each observation includes the factors related to the order like total bill, time, the total number of people in a group, gender of the person paying for the order and so on.
#
# #### Attribute Information:
#
# - **total_bill:** Total bill (cost of the meal), including tax, in US dollars
# - **tip:** Tip in US dollars
# - **sex:** Sex of person paying for the meal
# - **smoker:** There is a smoker in a group or not
# - **day:** Day on which the order is served
# - **time:** Time of the order
# - **size:** Size of the group
#
# Food servers’ tips in restaurants may be influenced by many factors, including the nature of the restaurant, size of the party, and table locations in the restaurant. Restaurant managers need to know which factors matter when they assign tables to food servers. For the sake of staff morale, they usually want to avoid either the substance or the appearance of unfair
# treatment of the servers, for whom tips (at least in restaurants in the UnitedStates) are a major component of pay.

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv('/Users/mymacbook/python/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 1. Make a list of categorical and numerical columns in the data.

# %%
num_df = df.select_dtypes(include=['int64','int', 'float'])
num_df.shape
# Out:
# (244, 3)

# %%
cat_df = df.select_dtypes(include=['category'])
cat_df.shape
# Out:
# (244, 0)

# %% [markdown]
# ### 2. Compute the average bill amount for each day.

# %%
df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %% [markdown]
# ### 3. Which gender is more generous in giving tips?

# %%
df.groupby('sex').mean()['tip']
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %% [markdown]
# ### 4. According to the data, were there more customers for dinner or lunch?

# %%
df.groupby('time').count()
# Out:
#         total_bill  tip  sex  smoker  day  size
# time
# Dinner         176  176  176     176  176   176
# Lunch           68   68   68      68   68    68

# %% [markdown]
# ### 5. Based on the statistical summary, comment on the variable 'tip'

# %%
df['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# ### 6. Find the busiest day in terms of the orders?

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ### 7. Is the variable 'total_bill' skewed? If yes, identify the type of skewness. Support your answer with a plot

# %%
sns.distplot(df['total_bill'],
             hist=False, color='darkred',
            )
# Out:
# /Users/mymacbook/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### 8. Is the tip amount dependent on the total bill? Visualize the relationship with a appropriate plot and metric and write your findings.

# %%
tips_df['sex'].value_counts()*100/tips_df.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0t/xrxysysd5yvf3gv0_gm3860m0000gn/T/ipykernel_2797/733958564.py in <module>
# ----> 1 tips_df['sex'].value_counts()*100/tips_df.shape[0]
#
# NameError: name 'tips_df' is not defined

# %% [markdown]
# ### 9. What is the percentage of males and females in the dataset? and display it in the plot

# %%
df['sex'].value_counts(normalize=True)*100
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %% [markdown]
# ### 10. Compute the gender-wise count based on smoking habits and display it in the plot

# %%
tips_df.groupby('day').mean()['tip'].apply(lambda x:round(x,2)).plot(kind="bar”)
barplot = crosstb.plot.bar(rot=0)
crosstb=pd.crosstab(gender,smoker)
gender=df['sex']
smoker=df['smoker']
# Out:
#   File "/var/folders/0t/xrxysysd5yvf3gv0_gm3860m0000gn/T/ipykernel_2797/3194078658.py", line 1
#     tips_df.groupby('day').mean()['tip'].apply(lambda x:round(x,2)).plot(kind="bar”)
#                                                                                     ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ### 11. Compute the average tip amount given for different days and display it in the plot.

# %%
avg=df.day.value_count()
plt.bar(avg,index,avg.values,color='red')
plt.xlable('day')
plt.xlable('avg tip')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/0t/xrxysysd5yvf3gv0_gm3860m0000gn/T/ipykernel_2797/1121843216.py in <module>
# ----> 1 avg=df.day.value_count()
#       2 plt.bar(avg,index,avg.values,color='red')
#       3 plt.xlable('day')
#       4 plt.xlable('avg tip')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %% [markdown]
# ### 12. Is the average bill amount dependent on the size of the group? Visualize the relationship using appropriate plot and write your findings.

# %%
bill_size_corr=df[['total_bill','size']]
bill_size_corr.corr()
sns.heatmap(bill_size_corr.corr())

# %% [markdown]
# ### 13. Plot a horizontal boxplot to compare the bill amount based on gender

# %%
sns.boxplot(x='total bill', y= 'sex',data=df)
plt.show()

# %% [markdown]
# ### 14. Find the maximum bill amount for lunch and dinner on Saturday and Sunday

# %%
df.groupby(['time','day']as_index=False) ['total_bill'].max()
df_x[(df_x['day'] == 'sat') | (df_x['day'] == 'sun']

# %% [markdown]
# ### 15. Compute the percentage of missing values in the dataset.

# %%
df.isnull().sum()/len(df)*100

# %% [markdown]
# ### 16. Is there are any duplicate records in the dataset? If yes compute the count of the duplicate records and drop them.

# %%
len(df[df.duplicated()])

# %% [markdown]
# ### 17. Is there are any outliers present in the column 'total_bill'? If yes treat them with transformation approach, and plot a boxplot before and after the treatment

# %%
snd.boxplot.
plt.show()

# %% [markdown]
# ### 18. Is there are any outliers present in the column 'tip'? If yes remove them using IQR techinque.

# %% [markdown]
# ### 19. Encode the categorical columns in the dataset and print the random 5 samples from the dataframe.

# %% [markdown]
# ### 20. Check the range of the column 'total_bill' and transform the values such that the range will be 1.

# %% [markdown]
# ### 21. Load the dataset again by giving the name of the dataframe as "tips_df"
# - i) Encode the categorical variables.
# - ii) Store the target column (i.e.tip) in the y variable and the rest of the columns in the X variable

# %% [markdown]
# ### 22. Split the dataset into two parts (i.e. 70% train and 30% test), and Standardize the columns "total_bill" and "Size" using the mim_max scaling approach

# %% [markdown]
# ### 23. Train a linear regression model using the training data and print the r_squared value of the prediction on the test data.

# %% [markdown]
# ### Happy Learning:)
